# %% [markdown]
# ### Martin Muga
# ### Email: martinmuga04@gmail.com
# #### Summary

# %% [markdown]
# I used Jupyter Notebooks together with Google Colab Notebooks to write the code.
# The programming language I used was python due to its simplicity, easy syntax and awesome community that has several learning resources online.
# The dataset used all throughout is the Traffic Jam: Predicting People's Movement into Nairobi dataset from Zindi Africa. I particularly used the trained revised.csv file found in the dataset

# %% [markdown]
# #### Solution.

# %% [markdown]
# For Question 1, I decided to add travel_route and travel_day rows. travel_route concatenates travel_from and travel_to rows into one and therefore shows the route travelled ie Migori-Nairobi routes.
# travel_day shows the day in which a passanger travelled ie Sunday. For this, I changed the csv date format from DD-MM-YYYY to
# MM/DD/YYYY as the latter was easier to use in the csv file.
# I then used the formula =TEXT(E2,"dddd") to add the day that corresponds to the date.
# I saved the updated csv file as train_revised_added_travel_day_travel_route - train_revised.csv
# I then used pyplot to plot an average_frequency bar graph and then ordered the graph in a descending order in order to rank the routes in a descending order.

# %%
#Loading the data
import pandas as pd
df = pd.read_csv('train_revised_q_one.csv')
df
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    10/17/17
# 1         5437         14A          Mpesa      TIHLBUSGTE    11/19/17
# 2         5710          8B          Mpesa      EQX8Q5G19O    11/26/17
# 3         5777         19A          Mpesa      SGP18CL0ME    11/27/17
# 4         5778         11A          Mpesa      BM97HFRGL9    11/27/17
# ...        ...         ...            ...             ...         ...
# 51640    13826          9B          Mpesa      8V2XDDZR6V     4/20/18
# 51641    13809         18A          Mpesa      4PEBSVJSNK     4/20/18
# 51642    13809         17A          Mpesa      LVN64LZDNN     4/20/18
# 51643    13796         16B          Mpesa      REYBSKTYWN     4/20/18
# 51644    14304           7          Mpesa      AQN7FBUSGP    11/14/17
#
#       travel_day travel_time travel_from travel_to      travel_route car_type  \
# 0        Tuesday       07:15      Migori   Nairobi    Migori-Nairobi      Bus
# 1         Sunday       07:12      Migori   Nairobi    Migori-Nairobi      Bus
# 2         Sunday       07:05      Keroka   Nairobi    Keroka-Nairobi      Bus
# 3         Monday       07:10    Homa Bay   Nairobi  Homa Bay-Nairobi      Bus
# 4         Monday       07:12      Migori   Nairobi    Migori-Nairobi      Bus
# ...          ...         ...         ...       ...               ...      ...
# 51640     Friday       08:00      Awendo   Nairobi    Awendo-Nairobi      Bus
# 51641     Friday       08:00      Migori   Nairobi    Migori-Nairobi      Bus
# 51642     Friday       08:00      Migori   Nairobi    Migori-Nairobi      Bus
# 51643     Friday       07:08      Awendo   Nairobi    Awendo-Nairobi      Bus
# 51644    Tuesday       05:10       Kisii   Nairobi     Kisii-Nairobi      Bus
#
#        max_capacity
# 0                49
# 1                49
# 2                49
# 3                49
# 4                49
# ...             ...
# 51640            49
# 51641            49
# 51642            49
# 51643            49
# 51644            49
#
# [51645 rows x 12 columns]

# %%
only_sunday = df['travel_day'].str.contains("Sunday")
df[only_sunday]
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 1         5437         14A          Mpesa      TIHLBUSGTE    11/19/17
# 2         5710          8B          Mpesa      EQX8Q5G19O    11/26/17
# 111       5856           9           Cash      MDF1ULUMPX     4/15/18
# 112       5857           6           Cash      MDF1ULG1GR     4/15/18
# 113       5857           3           Cash      MDF6ULD8NQ     4/15/18
# ...        ...         ...            ...             ...         ...
# 49784    13534          8A          Mpesa      DDLUTQQJ2C     4/15/18
# 49785    13534          7A          Mpesa      GVJSWN57XJ     4/15/18
# 49786    13535         15A          Mpesa      MI27JEXM0L     4/15/18
# 49787    13541          2B          Mpesa      ICOT1CSM7F     4/15/18
# 49788    13547         15A          Mpesa      X9XZAPYDCG     4/15/18
#
#       travel_day travel_time travel_from travel_to      travel_route car_type  \
# 1         Sunday       07:12      Migori   Nairobi    Migori-Nairobi      Bus
# 2         Sunday       07:05      Keroka   Nairobi    Keroka-Nairobi      Bus
# 111       Sunday       05:20       Kisii   Nairobi     Kisii-Nairobi  shuttle
# 112       Sunday       05:00       Kisii   Nairobi     Kisii-Nairobi  shuttle
# 113       Sunday       05:00       Kisii   Nairobi     Kisii-Nairobi  shuttle
# ...          ...         ...         ...       ...               ...      ...
# 49784     Sunday       19:07      Sirare   Nairobi    Sirare-Nairobi      Bus
# 49785     Sunday       19:07      Sirare   Nairobi    Sirare-Nairobi      Bus
# 49786     Sunday       08:00      Awendo   Nairobi    Awendo-Nairobi      Bus
# 49787     Sunday       07:13    Kehancha   Nairobi  Kehancha-Nairobi      Bus
# 49788     Sunday       07:05        Sori   Nairobi      Sori-Nairobi      Bus
#
#        max_capacity
# 1                49
# 2                49
# 111              11
# 112              11
# 113              11
# ...             ...
# 49784            49
# 49785            49
# 49786            49
# 49787            49
# 49788            49
#
# [7819 rows x 12 columns]

# %%
df[only_sunday].to_csv('data.csv')
data = pd.read_csv('data.csv')
data
# Out:
#       Unnamed: 0  ride_id seat_number payment_method payment_receipt  \
# 0              1     5437         14A          Mpesa      TIHLBUSGTE
# 1              2     5710          8B          Mpesa      EQX8Q5G19O
# 2            111     5856           9           Cash      MDF1ULUMPX
# 3            112     5857           6           Cash      MDF1ULG1GR
# 4            113     5857           3           Cash      MDF6ULD8NQ
# ...          ...      ...         ...            ...             ...
# 7814       49784    13534          8A          Mpesa      DDLUTQQJ2C
# 7815       49785    13534          7A          Mpesa      GVJSWN57XJ
# 7816       49786    13535         15A          Mpesa      MI27JEXM0L
# 7817       49787    13541          2B          Mpesa      ICOT1CSM7F
# 7818       49788    13547         15A          Mpesa      X9XZAPYDCG
#
#      travel_date travel_day travel_time travel_from travel_to  \
# 0       11/19/17     Sunday       07:12      Migori   Nairobi
# 1       11/26/17     Sunday       07:05      Keroka   Nairobi
# 2        4/15/18     Sunday       05:20       Kisii   Nairobi
# 3        4/15/18     Sunday       05:00       Kisii   Nairobi
# 4        4/15/18     Sunday       05:00       Kisii   Nairobi
# ...          ...        ...         ...         ...       ...
# 7814     4/15/18     Sunday       19:07      Sirare   Nairobi
# 7815     4/15/18     Sunday       19:07      Sirare   Nairobi
# 7816     4/15/18     Sunday       08:00      Awendo   Nairobi
# 7817     4/15/18     Sunday       07:13    Kehancha   Nairobi
# 7818     4/15/18     Sunday       07:05        Sori   Nairobi
#
#           travel_route car_type  max_capacity
# 0       Migori-Nairobi      Bus            49
# 1       Keroka-Nairobi      Bus            49
# 2        Kisii-Nairobi  shuttle            11
# 3        Kisii-Nairobi  shuttle            11
# 4        Kisii-Nairobi  shuttle            11
# ...                ...      ...           ...
# 7814    Sirare-Nairobi      Bus            49
# 7815    Sirare-Nairobi      Bus            49
# 7816    Awendo-Nairobi      Bus            49
# 7817  Kehancha-Nairobi      Bus            49
# 7818      Sori-Nairobi      Bus            49
#
# [7819 rows x 13 columns]

# %%
trips_count= data['travel_route'].value_counts()
trips_count
# Out:
# Kisii-Nairobi        3607
# Migori-Nairobi        954
# Homa Bay-Nairobi      944
# Sirare-Nairobi        634
# Rongo-Nairobi         575
# Kehancha-Nairobi      294
# Awendo-Nairobi        270
# Keroka-Nairobi        145
# Kijauri-Nairobi       138
# Nyachenge-Nairobi     107
# Mbita-Nairobi          73
# Rodi-Nairobi           50
# Ndhiwa-Nairobi         22
# Sori-Nairobi            3
# Keumbu-Nairobi          3
# Name: travel_route, dtype: int64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

#data = data.groupby('travel_route').mean

data['travel_route'].value_counts().plot(ax=ax, kind ='bar',) 
plt.xlabel =('travel_route')
plt.ylabel=('trips_count')
plt.title= ('travel_route vs trip_count')
plt.grid()
plt.show()
